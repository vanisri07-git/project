# %%
import pandas as pd

# %%
car=pd.read_csv(r"C:\Users\vanis\OneDrive\Desktop\car project\large_car_data_project.csv")

# %%
# Find all null value in the dataset if there is any null value in any column,
# then fill it with the mean of that column
car.isnull().sum()
# Out:
# Car_ID          0
# Brand           0
# Model           0
# Year            0
# Fuel_Type       0
# Engine_Size     0
# Transmission    0
# Price           0
# Color           0
# Mileage_kmpl    0
# Seats           0
# Owner_Type      0
# dtype: int64

# %%
car['Mileage_kmpl'].fillna(car['Mileage_kmpl'].mean(),inplace=True)
car
# Out:
# C:\Users\vanis\AppData\Local\Temp\ipykernel_20664\3002480344.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car['Mileage_kmpl'].fillna(car['Mileage_kmpl'].mean(),inplace=True)
#      Car_ID       Brand     Model  Year Fuel_Type Engine_Size Transmission  \
# 0         1        Ford   Corolla  2017    Petrol        2.2L       Manual
# 1         2         Kia  3 Series  2023    Diesel        1.8L          CVT
# 2         3        Ford     Jetta  2020    Hybrid        1.4L       Manual
# ...

# %%
#check what are the different types of make are there in our dataset and,
#What is the count (occurrence) of each make in the data
print(car.head())
car['Brand'].value_counts()
# Out:
#    Car_ID    Brand     Model  Year Fuel_Type Engine_Size Transmission  Price  \
# 0       1     Ford   Corolla  2017    Petrol        2.2L       Manual  35465
# 1       2      Kia  3 Series  2023    Diesel        1.8L          CVT  16835
# 2       3     Ford     Jetta  2020    Hybrid        1.4L       Manual  19280
# 3       4    Tesla     Forte  2015    Hybrid        1.2L          CVT  10660
# 4       5  Hyundai   C-Class  2017    Diesel        2.4L       Manual  34074
#
#     Color  Mileage_kmpl  Seats Owner_Type
# 0  Yellow          12.0      4      Third
# 1    Grey          12.0      4      Third
# 2   White          13.0      6      First
# 3    Grey          10.7      7      First
# 4  Silver          17.6      6     Second
# Brand
# Tesla         42
# Ford          39
# Volkswagen    37
# BMW           37
# Honda         34
# Hyundai       34
# Nissan        34
# Kia           32
# Mercedes      30
# Toyota        29
# Audi          27
# Chevrolet     25
# ...

# %%
# Show all the records where Year 2015 or 2017
car[car['Year'].isin([2015,2017])]
# Out:
#      Car_ID    Brand    Model  Year Fuel_Type Engine_Size Transmission  Price  \
# 0         1     Ford  Corolla  2017    Petrol        2.2L       Manual  35465
# 3         4    Tesla    Forte  2015    Hybrid        1.2L          CVT  10660
# 4         5  Hyundai  C-Class  2017    Diesel        2.4L       Manual  34074
# 7         8   Nissan    Forte  2017  Electric        1.6L          CVT  24045
# 8         9  Hyundai  Elantra  2017    Petrol        2.0L    Automatic  53144
# ..      ...      ...      ...   ...       ...         ...          ...    ...
# 388     389    Tesla    Cruze  2015    Petrol        1.2L    Automatic  32495
# 390     391     Audi    Forte  2017    Diesel        1.6L       Manual  46078
# 391     392    Honda    Cruze  2015  Electric        1.8L    Automatic  56866
# 397     398  Hyundai   Altima  2017  Electric          0L          CVT  59178
# 399     400  Hyundai  Corolla  2015    Petrol          0L          CVT  55336
#
# ...

# %%
# Remove all the records (rows) where Price is above 55000
car[~(car['Price']>55000)]
# Out:
#      Car_ID       Brand     Model  Year Fuel_Type Engine_Size Transmission  \
# 0         1        Ford   Corolla  2017    Petrol        2.2L       Manual
# 1         2         Kia  3 Series  2023    Diesel        1.8L          CVT
# 2         3        Ford     Jetta  2020    Hybrid        1.4L       Manual
# 3         4       Tesla     Forte  2015    Hybrid        1.2L          CVT
# 4         5     Hyundai   C-Class  2017    Diesel        2.4L       Manual
# ..      ...         ...       ...   ...       ...         ...          ...
# 393     394  Volkswagen     Civic  2018  Electric        1.4L          CVT
# 394     395     Hyundai     Jetta  2023    Hybrid        1.8L       Manual
# 395     396        Audi   Corolla  2021  Electric          0L    Automatic
# 396     397  Volkswagen    Altima  2021    Hybrid        2.0L       Manual
# 398     399         BMW   Model 3  2018    Diesel          0L       Manual
#
#      Price   Color  Mileage_kmpl  Seats Owner_Type
# ...

# %%
#Increase all the values of 'Seats' column by 2
car['Seats']=car['Seats'].apply(lambda a:a+2)
car
# Out:
#      Car_ID       Brand     Model  Year Fuel_Type Engine_Size Transmission  \
# 0         1        Ford   Corolla  2017    Petrol        2.2L       Manual
# 1         2         Kia  3 Series  2023    Diesel        1.8L          CVT
# 2         3        Ford     Jetta  2020    Hybrid        1.4L       Manual
# 3         4       Tesla     Forte  2015    Hybrid        1.2L          CVT
# 4         5     Hyundai   C-Class  2017    Diesel        2.4L       Manual
# ..      ...         ...       ...   ...       ...         ...          ...
# 395     396        Audi   Corolla  2021  Electric          0L    Automatic
# 396     397  Volkswagen    Altima  2021    Hybrid        2.0L       Manual
# 397     398     Hyundai    Altima  2017  Electric          0L          CVT
# 398     399         BMW   Model 3  2018    Diesel          0L       Manual
# 399     400     Hyundai   Corolla  2015    Petrol          0L          CVT
#
#      Price   Color  Mileage_kmpl  Seats Owner_Type
# ...
